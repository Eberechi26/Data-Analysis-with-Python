# %%
# Imported important files

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
# Read the Excel and displayed the first five rows

df = pd.read_excel('EBERECHI MAUREEN NWANKWO_8145497791_20250416095037.xlsx')
df.head()
# Out:
#               Trans. Time Value Date  \
# 0  2024 Mar 21 22:12:\n19 2024-03-21
# 1  2024 Mar 25 12:48:\n24 2024-03-25
# 2  2024 Mar 25 13:18:\n26 2024-03-25
# 3  2024 Mar 27 08:\n59:49 2024-03-27
# 4  2024 Mar 28 08:\n37:58 2024-03-28
#
#                                     Description  Debit/Credit(₦)  Balance(₦)  \
# 0                           Add Money-Bank USSD          13300.0     13300.0
# 1       Transfer to Shehu umar provisions store          -3500.0      9800.0
# 2        Transfer from NWANKWO EBERECHI MAUREEN           3500.0     13300.0
# 3  Transfer to DE-CREATIVE ARTS CONSULT AND PRI          -4500.0      8800.0
# 4                    Transfer to FORBBIES HAIRS          -5000.0      3800.0
#
#      Channel           Transaction Reference
# 0  E-Channel              240321031864561528
# 1  E-Channel              240325026876769097
# 2  E-Channel  000016240325141824000010482401
# 3  E-Channel              240327020437473355
# 4  E-Channel              240328027010858986

# %%
# Statistical Description of the numerical columns

df.describe()
# Out:
#        Debit/Credit(₦)    Balance(₦)
# count       268.000000    268.000000
# mean         18.733209  12307.449627
# std        4586.656917  10136.444504
# min      -21000.000000      0.000000
# 25%       -2000.000000   5087.500000
# 50%         500.000000  10343.750000
# 75%        1400.000000  16211.500000
# max       30000.000000  47299.000000

# %%
# Number of rows and columns

df.shape
# Out:
# (498, 7)

# %% [markdown]
# # Data Preparation

# %%
# number of null values in each of the columns

df1 = df.isnull().sum()
df1
# Out:
# Trans. Time                3
# Value Date               230
# Description              227
# Debit/Credit(₦)          230
# Balance(₦)               230
# Channel                  230
# Transaction Reference    223
# dtype: int64

# %%
# Total Credit/Debit Values respectively

# Calculate total credit (positive values)
total_credit = df[df['Debit/Credit(₦)'] > 0]['Debit/Credit(₦)'].sum()

# Calculate total debit (negative values, we'll make it positive for reporting)
total_debit = abs(df[df['Debit/Credit(₦)'] < 0]['Debit/Credit(₦)'].sum())

print(f"Total Credit: ₦{total_credit:.2f}")
print(f"Total Debit: ₦{total_debit:.2f}")
# Out:
# Total Credit: ₦380050.00
# Total Debit: ₦375029.50

# %%
# Spliting the credit and debit in different columns

df['total_credit'] = df[df['Debit/Credit(₦)'] > 0]['Debit/Credit(₦)']
df['total_debit'] = abs(df[df['Debit/Credit(₦)'] < 0]['Debit/Credit(₦)'])

# %%
# filled up the null values of the credit and debit column

df['total_credit']= df['total_credit'].ffill()
df['total_debit']= df['total_debit'].ffill()

# %%
# top five credit sources

top_5_credit = df.nlargest(5,'total_credit')
top_5_credit
# Out:
#               Trans. Time Value Date                        Description  \
# 234    2024 Jul 23 21:00: 2024-07-23  Transfer from DANIEL CHIKE EZEALA
# 235                    27        NaT                                NaN
# 236  2024 Jul 24 10:15:31 2024-07-24   Transfer to JOHN EJELEKWU STEVEN
# 237    2024 Jul 24 18:40: 2024-07-24    Transfer to CHIMA STEPHEN OKEKE
# 238                    34        NaT                                NaN
#
#      Debit/Credit(₦)  Balance(₦)    Channel           Transaction Reference  \
# 234          30000.0     30999.0  E-Channel  000004240723220052215989635019
# 235              NaN         NaN        NaN                             NaN
# 236          -2800.0     28199.0  E-Channel              240724015071038403
# 237          -3500.0     24699.0  E-Channel  100004240724184042117153219660
# 238              NaN         NaN        NaN                             NaN
#
#      total_credit  total_debit
# 234       30000.0       1500.0
# 235       30000.0       1500.0
# 236       30000.0       2800.0
# 237       30000.0       3500.0
# 238       30000.0       3500.0

# %%
top_5_debit = df.nlargest(5,'total_debit')
top_5_debit
# Out:
#             Trans. Time Value Date                        Description  \
# 363  2024 Oct 08 15:20: 2024-10-08  Transfer to STEVEN, EJELEKWU JOHN
# 364                  49        NaT                                NaN
# 365  2024 Oct 08 18:21: 2024-10-08  Transfer from CHIMA STEPHEN OKEKE
# 366                  23        NaT                                NaN
# 367  2024 Oct 08 18:30: 2024-10-08  Transfer from DANIEL CHIKE EZEALA
#
#      Debit/Credit(₦)  Balance(₦)    Channel           Transaction Reference  \
# 363         -21000.0      2249.0  E-Channel  100004241008152059120364981656
# 364              NaN         NaN        NaN                             NaN
# 365           3000.0      5249.0  E-Channel  000004241008192123913347694239
# 366              NaN         NaN        NaN                             NaN
# 367           5000.0     10249.0  E-Channel  000014241008193022254789107996
#
#      total_credit  total_debit
# 363        7000.0      21000.0
# 364        7000.0      21000.0
# 365        3000.0      21000.0
# 366        3000.0      21000.0
# 367        5000.0      21000.0

# %%
# filling the null values in channel and balance columns

df4 = df['Balance(₦)'].median()
df['Balance(₦)'] = df['Balance(₦)'].fillna(df4)

df = df[['Value Date', 'Channel' ]].ffill()

# %%
# converting the date column to datetime

df['Value Date'] = pd.to_datetime(df['Value Date'])

# %% [markdown]
# # Data Exploration

# %%
# Exploring the rate of income per month

df['Value Month'] = df['Value Date'].dt.month

# aggregate total credit by value month
monthly_value = df.groupby('Value Month')['total_credit'].sum()

fig = go.Figure(data=[
    go.Scatter(
        x=monthly_value.index,
        y=monthly_value.values,
        marker=dict(color='red'),
        line=dict(color='blue')
    )
])

fig.update_layout(
    title='Total Monthly Income',
    xaxis_title='Month',
    yaxis_title='Total Credit',
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(1, 13)),
        ticktext=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    ),
    height=600,
    width=1000
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [11], in <cell line: 6>()
#       3 df['Value Month'] = df['Value Date'].dt.month
#       5 # aggregate total credit by value month
# ----> 6 monthly_value = df.groupby('Value Month')['total_credit'].sum()
#       8 fig = go.Figure(data=[
#       9     go.Scatter(
#      10         x=monthly_value.index,
#    (...)
#      14     )
#      15 ])
#      17 fig.update_layout(
#      18     title='Total Monthly Income',
#      19     xaxis_title='Month',
#    (...)
#      27     width=1000
#      28 )
#
# File ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py:1338, in DataFrameGroupBy.__getitem__(self, key)
#    1329 if isinstance(key, tuple) and len(key) > 1:
#    1330     # if len == 1, then it becomes a SeriesGroupBy and this is actually
#    1331     # valid syntax, so don't raise warning
#    1332     warnings.warn(
#    1333         "Indexing with multiple keys (implicitly converted to a tuple "
#    1334         "of keys) will be deprecated, use a list instead.",
#    1335         FutureWarning,
#    1336         stacklevel=find_stack_level(),
#    1337     )
# -> 1338 return super().__getitem__(key)
#
# File ~\anaconda3\lib\site-packages\pandas\core\base.py:250, in SelectionMixin.__getitem__(self, key)
#     248 else:
#     249     if key not in self.obj:
# --> 250         raise KeyError(f"Column not found: {key}")
#     251     subset = self.obj[key]
#     252     ndim = subset.ndim
#
# KeyError: 'Column not found: total_credit'

# %%
# exploring the rate of expenses by month 

# aggregate total debit by Value month
monthly_value = df.groupby('Value Month')['total_debit'].sum()

fig = go.Figure(data=[
    go.Scatter(
        x=monthly_value.index,
        y=monthly_value.values,
        marker=dict(color='red'),
        line=dict(color='blue')
    )
])

fig.update_layout(
    title='Total Monthly Debit',
    xaxis_title='Month',
    yaxis_title='Total Debit',
    xaxis=dict(
        tickmode='array',
        tickvals=list(range(1, 13)),
        ticktext=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    ),
    height=600,
    width=1000
)

fig.show()

# %%
# exploring the total credit per weekday

df['Value Day'] = df['Value Date'].dt.day_name()

weekday_value = df['Value Day'].value_counts().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

# aggregate total credit by day of the week
weekday_inflow = df.groupby('Value Day')['total_credit'].sum().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=weekday_value.index,
        y=weekday_value.values,
        name='Income',
        marker_color='blue',
        opacity=0.6,
        yaxis='y1'
    )
)

fig.add_trace(
    go.Scatter(
        x=weekday_inflow.index,
        y=weekday_inflow.values,
        name='Total Credit',
        mode='lines+markers',
        marker=dict(color='red'),
        line=dict(color='red'),
        yaxis='y2'
    )
)

fig.update_layout(
    title='Weekly Cash Inflow',
    xaxis=dict(
        title='Day of the Week',
        categoryorder ='array',
        categoryarray=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    ),
    yaxis=dict(
        title='Total Income',
        showgrid=False,
        side='left',
    ),
    yaxis2=dict(
        title='Total Income',
        overlaying='y',
        side='right',
        showgrid=False
    ), 
    legend=dict(
        x=1.05,
        y=1,
        orientation='v',
        xanchor='left'
    ),
    height=600,
    width=1000
)


fig.show()

# %%
# exploring the total credit per weekday


weekday_inflow = df.groupby('Value Day')['total_debit'].sum().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
)

fig = go.Figure()

fig.add_trace(
    go.Bar(
        x=weekday_value.index,
        y=weekday_value.values,
        name='Expense',
        marker_color='red',
        opacity=0.6,
        yaxis='y1'
    )
)

fig.add_trace(
    go.Scatter(
        x=weekday_inflow.index,
        y=weekday_inflow.values,
        name='Total Debit',
        mode='lines+markers',
        marker=dict(color='blue'),
        line=dict(color='blue'),
        yaxis='y2'
    )
)

fig.update_layout(
    title='Weekly Cash Outflow',
    xaxis=dict(
        title='Day of the Week',
        categoryorder ='array',
        categoryarray=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
    ),
    yaxis=dict(
        title='Total Expenses',
        showgrid=False,
        side='left',
    ),
    yaxis2=dict(
        title='Total Expenses',
        overlaying='y',
        side='right',
        showgrid=False
    ), 
    legend=dict(
        x=1.05,
        y=1,
        orientation='v',
        xanchor='left'
    ),
    height=600,
    width=1000
)


fig.show()
